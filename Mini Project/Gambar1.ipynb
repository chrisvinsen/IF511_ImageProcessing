# %%
from ipynb.fs.full.MiniProjectFunction import *

main("asdf.jpg")
# Out:
# HSV Image
# PSNR value is 29.133328972793787 dB
# MSE value is 39354.32265938465 dB
# Histogram Equalization
# PSNR value is 29.399302581930293 dB
# MSE value is 1550.5151554060571 dB
# Contrast Stretching
# PSNR value is 30.708976838188747 dB
# MSE value is 681.0255667679398 dB
# CLAHE
# PSNR value is 32.83102150295135 dB
# MSE value is 774.5300295380016 dB
# Mean Filter
# PSNR value is 29.365087384460736 dB
# MSE value is 1481.789098427855 dB
# Median Filter
# PSNR value is 29.359824483073535 dB
# MSE value is 1522.6286779031636 dB
# Gaussian Filter
# PSNR value is 29.433070436903446 dB
# MSE value is 1474.0208503327547 dB
# Outline Image Filter
# PSNR value is 28.51504474847761 dB
# MSE value is 27132.3340588831 dB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9b3e39826171> in <module>
#       1 from ipynb.fs.full.MiniProjectFunction import *
#       2
# ...
